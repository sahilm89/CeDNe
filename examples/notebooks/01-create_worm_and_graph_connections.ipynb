# %% [markdown]
# # Loading and graphing the connectivity of a worm.
# ### This is a basic example of loading a Worm object and graphing its connectivity. Here we also apply an attribute to a subset of the neurons and then subset the network based on this attribute.

# %%
from cedne import utils
# Out:
# /Users/sahilmoza/Library/Caches/pypoetry/virtualenvs/cedne-OqN2BZQP-py3.12/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Create a worm and its nervous system

# %%
w = utils.makeWorm()
nn = w.conditions["Neutral"]

# %% [markdown]
# ### Set a property on a subset of neurons called "sensory-stim". This could in principle be a stimlus or any measurement made from the worm nervous system.

# %%
for n in nn.neuronDict:
    if nn.neuronDict[n].type == 'sensory' and nn.neuronDict[n].modality == 'amphid':
        nn.neuronDict[n].setProperty('sensory-stim', True)

# %% [markdown]
# ### Subgraph the nervous system based on this property

# %%
g = nn.returnNetworkWhere(neuronsHave = {'sensory-stim': True})

# %% [markdown]
# ### Plot the network as a spiral: Orange connections are chemical synapses and gray connections are gap junctions.

# %%
utils.makeSpiral(g)
