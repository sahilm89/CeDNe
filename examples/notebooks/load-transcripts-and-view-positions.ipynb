# %% [markdown]
# # View positions and select neurons based on transcripts
# ### Here we look at ways to view positions of specific neurons in the neuronal network in different orientations, and select a subset of neurons based on their transcripts.

# %%
from cedne import utils
# Out:
# /Users/sahilmoza/Library/Caches/pypoetry/virtualenvs/cedne-OqN2BZQP-py3.12/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Load the worm and neural network as usual

# %%
w = utils.makeWorm()
nn = w.conditions["Neutral"]

# %% [markdown]
# ### This function allows plotting to view the positions of the neurons and highlight a subset of neurons

# %%
utils.plot_position(nn, highlight=['RMED', 'RMEV'], axis='AP-VD')
# Out:
# /Users/sahilmoza/Library/Caches/pypoetry/virtualenvs/cedne-OqN2BZQP-py3.12/lib/python3.12/site-packages/textalloc/__init__.py:306: UserWarning: Usage of allocate_text will be replaced with allocate in future releases, removing the need for the fig argument
#   warnings.warn(

# %% [markdown]
# ### Now we load the CENGEN transcipts

# %%
utils.loadTranscripts(nn)
cengen_threshold_level = 4
transcript_of_interest =  'twnk-1'

# %%
neurons_of_interest = [n.name for n,t in nn.neuronsHave('transcript').items() if t[cengen_threshold_level][transcript_of_interest]]

# %%
utils.plot_position(nn, highlight=neurons_of_interest, axis='AP-DV')
# Out:
# /Users/sahilmoza/Library/Caches/pypoetry/virtualenvs/cedne-OqN2BZQP-py3.12/lib/python3.12/site-packages/textalloc/__init__.py:306: UserWarning: Usage of allocate_text will be replaced with allocate in future releases, removing the need for the fig argument
#   warnings.warn(

# %% [markdown]
# ### We can also look at intersections of several CENGEN transcripts together, which can sometimes be useful to design promoters.

# %%
transcripts_of_interest =  ['sre-1', 'sre-6']

# %%
neurons_of_interest = [n.name for n,t in nn.neuronsHave('transcript').items() if all (t[cengen_threshold_level][transcript_of_interest] for transcript_of_interest in transcripts_of_interest)]

# %%
utils.plot_position(nn, highlight=neurons_of_interest, axis='AP-LR')

# %% [markdown]
# ### View positions of neurons of interest and neighbours in a 3D plot.

# %%
for n,neu in nn.neurons.items():
    print(n, neu.transcript)
# Out:
# ASJL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASJ, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASJ, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASJ, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASJ, Length: 13669, dtype: bool}
# ASJR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASJ, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASJ, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASJ, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASJ, Length: 13669, dtype: bool}
# ASKL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASK, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASK, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASK, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASK, Length: 13669, dtype: bool}
# ASKR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASK, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASK, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASK, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASK, Length: 13669, dtype: bool}
# ASGL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASG, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASG, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASG, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASG, Length: 13669, dtype: bool}
# ASGR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASG, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASG, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASG, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASG, Length: 13669, dtype: bool}
# ASIL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASI, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASI, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASI, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASI, Length: 13669, dtype: bool}
# ASIR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASI, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASI, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASI, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASI, Length: 13669, dtype: bool}
# AFDL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AFD, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AFD, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AFD, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AFD, Length: 13669, dtype: bool}
# AFDR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AFD, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AFD, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AFD, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AFD, Length: 13669, dtype: bool}
# AWAL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWA, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWA, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWA, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWA, Length: 13669, dtype: bool}
# AWAR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWA, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWA, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWA, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWA, Length: 13669, dtype: bool}
# AWBL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWB, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWB, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWB, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWB, Length: 13669, dtype: bool}
# AWBR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWB, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWB, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWB, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWB, Length: 13669, dtype: bool}
# AWCL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWC_OFF, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWC_OFF, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWC_OFF, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWC_OFF, Length: 13669, dtype: bool}
# AWCR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AWC_ON, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWC_ON, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AWC_ON, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AWC_ON, Length: 13669, dtype: bool}
# ASEL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASEL, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASEL, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASEL, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASEL, Length: 13669, dtype: bool}
# ASER {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASER, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASER, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASER, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASER, Length: 13669, dtype: bool}
# ADFL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADF, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADF, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADF, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADF, Length: 13669, dtype: bool}
# ADFR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADF, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADF, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADF, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADF, Length: 13669, dtype: bool}
# ASHL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASH, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASH, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASH, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASH, Length: 13669, dtype: bool}
# ASHR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ASH, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASH, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ASH, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ASH, Length: 13669, dtype: bool}
# ADLL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADL, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADL, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADL, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADL, Length: 13669, dtype: bool}
# ADLR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADL, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADL, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADL, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADL, Length: 13669, dtype: bool}
# BAGL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: BAG, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: BAG, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: BAG, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: BAG, Length: 13669, dtype: bool}
# BAGR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: BAG, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: BAG, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: BAG, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: BAG, Length: 13669, dtype: bool}
# URXL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1     True
# K01A6.18    False
# Name: URX, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: URX, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: URX, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: URX, Length: 13669, dtype: bool}
# URXR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1     True
# K01A6.18    False
# Name: URX, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: URX, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: URX, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: URX, Length: 13669, dtype: bool}
# ALNL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ALN, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALN, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALN, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ALN, Length: 13669, dtype: bool}
# ALNR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ALN, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALN, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALN, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ALN, Length: 13669, dtype: bool}
# PLNL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PLN, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLN, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLN, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PLN, Length: 13669, dtype: bool}
# PLNR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PLN, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLN, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLN, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PLN, Length: 13669, dtype: bool}
# SDQL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: SDQ, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: SDQ, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: SDQ, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: SDQ, Length: 13669, dtype: bool}
# SDQR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: SDQ, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: SDQ, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: SDQ, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: SDQ, Length: 13669, dtype: bool}
# AQR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AQR, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AQR, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AQR, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AQR, Length: 13669, dtype: bool}
# PQR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PQR, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PQR, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PQR, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PQR, Length: 13669, dtype: bool}
# ADEL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADE, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADE, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADE, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADE, Length: 13669, dtype: bool}
# ADER {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ADE, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADE, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ADE, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ADE, Length: 13669, dtype: bool}
# PDEL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PDE, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PDE, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PDE, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PDE, Length: 13669, dtype: bool}
# PDER {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PDE, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PDE, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PDE, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PDE, Length: 13669, dtype: bool}
# ALML {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ALM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ALM, Length: 13669, dtype: bool}
# ALMR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: ALM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: ALM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: ALM, Length: 13669, dtype: bool}
# AVM {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: AVM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AVM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: AVM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: AVM, Length: 13669, dtype: bool}
# PVM {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PVM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PVM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PVM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PVM, Length: 13669, dtype: bool}
# PLML {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PLM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PLM, Length: 13669, dtype: bool}
# PLMR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: PLM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: PLM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: PLM, Length: 13669, dtype: bool}
# FLPL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ...
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I3, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: I3, Length: 13669, dtype: bool}
# I4 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: I4, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I4, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I4, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: I4, Length: 13669, dtype: bool}
# I5 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: I5, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I5, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I5, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: I5, Length: 13669, dtype: bool}
# I6 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: I6, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I6, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: I6, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: I6, Length: 13669, dtype: bool}
# M1 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M1, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M1, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M1, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M1, Length: 13669, dtype: bool}
# M2L {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M2, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M2, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M2, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M2, Length: 13669, dtype: bool}
# M2R {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M2, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M2, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M2, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M2, Length: 13669, dtype: bool}
# M3L {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M3, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M3, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M3, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M3, Length: 13669, dtype: bool}
# M3R {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M3, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M3, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M3, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M3, Length: 13669, dtype: bool}
# M4 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M4, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M4, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M4, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M4, Length: 13669, dtype: bool}
# M5 {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: M5, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M5, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: M5, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: M5, Length: 13669, dtype: bool}
# MCL {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: MC, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MC, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MC, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: MC, Length: 13669, dtype: bool}
# MCR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: MC, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MC, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MC, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: MC, Length: 13669, dtype: bool}
# MI {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: MI, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MI, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: MI, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: MI, Length: 13669, dtype: bool}
# NSML {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: NSM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: NSM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: NSM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: NSM, Length: 13669, dtype: bool}
# NSMR {1: gene_name
# nduo-6       True
# ndfl-4       True
# MTCE.7       True
# nduo-1       True
# atp-6        True
#             ...
# ins-13      False
# K05F1.8     False
# ttr-7       False
# F07G11.1    False
# K01A6.18    False
# Name: NSM, Length: 13669, dtype: bool, 2: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C50D2.3      False
# gst-35       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: NSM, Length: 13669, dtype: bool, 3: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# T05D4.2      False
# R160.2       False
# C28C12.11    False
# T12F5.2      False
# ref-1        False
# Name: NSM, Length: 13669, dtype: bool, 4: gene_name
# nduo-6        True
# ndfl-4        True
# MTCE.7        True
# nduo-1        True
# atp-6         True
#              ...
# C28C12.11    False
# spp-13       False
# T12F5.2      False
# ref-1        False
# ttr-39       False
# Name: NSM, Length: 13669, dtype: bool}
